# %% [markdown]
# ¡Hola Carlos! Espero estés bien.
#
# Mi nombre es **Gina Buvoli**. Un gusto conocerte, seré tu revisora en este proyecto.
#
# A continuación, te comparto un poco sobre la modalidad de revisión que vamos a usar:
#
# Cuando encuentre un error por primera vez, simplemente lo señalaré y dejaré que lo detectes y corrijas por tu cuenta. Además, a lo largo del proyecto iré haciendo algunas observaciones para mejorar tu código, así como comentarios sobre tus conclusiones o percepciones sobre el tema.
#
# Si en algún momento no logras resolver la tarea, en la siguiente iteración te daré una pista más precisa, junto con algunos ejemplos prácticos. También estoy abierta a responder cualquier duda que tengas.
#
# Encontrarás mis comentarios a continuación: por favor, no los muevas, modifiques ni elimines.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora [#° iteración]</b> <a class="tocSkip"></a><br>
# <b>Éxito ✅</b><br>
# ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis. Continúa aplicando estas buenas prácticas en futuras secciones.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario de la revisora [#° iteración]</b> <a class="tocSkip"></a><br>
# <b>Atención ⚠️</b><br>
# El código es correcto, pero hay una recomendación de mejora. No bloquea la aprobación, pero vale la pena ajustarlo.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario de la revisora [#° iteración]</b> <a class="tocSkip"></a><br>
# <b>A resolver 🔴</b><br>
# Aquí hay un error que es necesario corregir para aprobar. Por favor revisa este punto antes de volver a enviar.
# </div>
#
# ---
#
# En cada revisión recibirás un **Comentario General** que resume los aspectos positivos, las áreas de mejora y los próximos pasos.
#
# También puedes responderme copiando el siguiente bloque si tienes alguna duda:
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante [#° iteración]</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta.
# </div>
#
# **¡Empecemos!** 🚀

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Review General. (Iteración 1)</b> <a class="tocSkip"></a>
#
# ¡Hola Carlos!
#
# Tu código muestra que dominas la parte técnica: la limpieza del Paso 3 es correcta en todos sus puntos, el merge y la agregación del Paso 4 están bien construidos, y tu análisis ejecutivo del Paso 7 es completo y bien razonado — identificas correctamente a los "power users" y usuarios Premium como el segmento más valioso, con recomendaciones concretas.
#
# Sin embargo, <b>hay seis puntos que deben corregirse antes de aprobar</b>. La mayoría son diagnósticos escritos que quedaron sin completar, más el archivo del notebook faltante en tu repositorio. Encontrarás el detalle y una guía paso a paso en cada sección correspondiente — tienes todo lo necesario para completarlos, ya que tu Paso 7 demuestra que entiendes el análisis a fondo.
#
# Vas por buen camino, enfócate en estos puntos y vuelve a enviar el proyecto.
# </div>

# %% [markdown]
# # Análisis ConnectaTel
#
# Como **analista de datos**, tu objetivo es evaluar el **comportamiento de los clientes** de una empresa de telecomunicaciones en Latinoamérica, ConnectaTel.
#
# Trabajaremos con información registrada **hasta el año 2024**, lo cual permitirá analizar el comportamiento del negocio dentro de ese periodo.
#
# Para ello trabajarás con tres datasets:
#
# - **plans.csv** → información de los planes actuales (precio, minutos incluidos, GB incluidos, costo por extra)
# - **users.csv** → información de los clientes (edad, ciudad, fecha de registro, plan, churn)
# - **usage.csv** → detalle del **uso real** de los servicios (llamadas y mensajes)
#
# Deberás **explorar**, **limpiar** y **analizar** estos datos para construir un **perfil estadístico** de los clientes, detectar **comportamientos atípicos** y crear **segmentos de clientes**.
#
# Este análisis te permitirá **identificar patrones de consumo**, **diseñar estrategias de retención** y **sugerir mejoras en los planes** ofrecidos por la empresa.
#
# > 💡 Antes de empezar, recuerda pensar de forma **programática**: ¿qué pasos necesitas? ¿En qué orden? ¿Qué quieres medir y por qué?

# %% [markdown]
# ---
# ## 🧩 Paso 1: Cargar y explorar
#
# Antes de limpiar o combinar los datos, es necesario **familiarizarte con la estructura de los tres datasets**.
# En esta etapa, validarás que los archivos se carguen correctamente, conocerás sus columnas y tipos de datos, y detectarás posibles inconsistencias.
#
# ### 1.1 Carga de datos y vista rápida
#
# **🎯 Objetivo:**
# Tener los **3 datasets listos en memoria**, entender su contenido y realizar una revisión preliminar.
#
# **Instrucciones:**
# - Importa las librerías necesarias (por ejemplo `pandas`, `seaborn`, `matplotlib.pyplot`)
# - Carga los archivos CSV usando `pd.read_csv()`:
#   - **`/datasets/plans.csv`**
#   - **`/datasets/users_latam.csv`**
#   - **`/datasets/usage.csv`**
# - Guarda los DataFrames en las variables: `plans`, `users`, `usage`.
# - Muestra las primeras filas de cada DataFrame usando `.head()`.

# %%
# importar librerías
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# cargar archivos[cite: 1]
plans = pd.read_csv('/datasets/plans.csv')
users = pd.read_csv('/datasets/users_latam.csv')
usage = pd.read_csv('/datasets/usage.csv')

# %%
# mostrar las primeras 5 filas de plans[cite: 1]
display(plans.head())

# %%
# mostrar las primeras 5 filas de users[cite: 1]
display(users.head())

# %%
# mostrar las primeras 5 filas de usage[cite: 1]
display(usage.head())

# %% [markdown]
# **Tip:** Si no usas `print()` la tabla se vera mejor.

# %% [markdown]
# ### 1.2 Exploración de la estructura de los datasets
#
# **🎯 Objetivo:**
# Conocer la **estructura de cada dataset**, revisar cuántas filas y columnas tienen, identificar los **tipos de datos** de cada columna y detectar posibles **inconsistencias o valores nulos** antes de iniciar el análisis.
#
# **Instrucciones:**
# - Revisa el **número de filas y columnas** de cada dataset usando `.shape`.
# - Usa `.info()` en cada DataFrame para obtener un **resumen completo** de columnas, tipos de datos y valores no nulos.

# %%
# revisar el número de filas y columnas de cada dataset[cite: 1]
print("plans", plans.shape)
print("users", users.shape)
print("usage", usage.shape)

# %%
# inspección de plans con .info()[cite: 1]
print("\n--- PLANS INFO ---")
plans.info()

# %%
# inspección de users con .info()[cite: 1]
print("\n--- USERS INFO ---")
users.info()

# %%
# inspección de usage con .info()[cite: 1]
print("\n--- USAGE INFO ---")
usage.info()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora. (Iteración 1)</b> <a class="tocSkip"></a>
# ¡Buen inicio! Importaste las librerías necesarias, cargaste los 3 datasets correctamente con <code>users_latam.csv</code>, y exploraste la estructura con <code>.shape</code> e <code>.info()</code>. Todo listo para el análisis de calidad.
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 2: Identificación de problemas de calidad de datos
#
# ### 2.1 Revisión de valores nulos
#
# **🎯 Objetivo:**
# Detectar la presencia y magnitud de valores faltantes para evaluar si afectan el análisis o requieren imputación/eliminación.
#
# **Instrucciones:**
# - Cuenta valores nulos por columna para cada dataset.
# - Calcula la proporción de nulos por columna para cada dataset.
#
# El dataset `plans` solamente tiene 2 renglones y se puede observar que no tiene ausentes, por ello no necesita exploración adicional.
#
# <br>
# <details>
# <summary>Haz clic para ver la pista</summary>
# Usa `.isna().sum()` para contar valores nulos y usa `.isna().mean()` para calcular la proporción.

# %%
## Cantidad de valores nulos para users
print("--- Valores nulos en users ---")
print(users.isna().sum())

print("\n--- Proporción de valores nulos en users ---")
print(users.isna().mean())

# %%
# Cantidad de valores nulos para usage
print("\n--- Valores nulos en usage ---")
print(usage.isna().sum())

print("\n--- Proporción de valores nulos en usage ---")
print(usage.isna().mean())

# %% [markdown]
# city (Datos demográficos): Al tratarse de una variable categórica con un porcentaje bajo de nulos, se propone imputar con la moda (la categoría más frecuente o un valor genérico como "Desconocido") para evitar perder registros valiosos de clientes.
#
# churn_date (Baja de clientes): Al presentar un porcentaje elevado de valores nulos, se mantiene como nulo dado que representan a los clientes activos que no han cancelado el servicio; imputarlos distorsionaría el análisis de churn.
#
# duration y length (Uso del servicio): Se decide dejar como nulos ya que estos valores faltantes están asociados directamente al tipo de plan o a la inactividad temporal del usuario (patrón MAR), por lo que eliminar filas o imputar un promedio alteraría el comportamiento real del consumo.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de la revisora. (Iteración 1)</b> <a class="tocSkip"></a>
# El código de nulos está bien ejecutado con <code>.isna().sum()</code> y <code>.isna().mean()</code> para ambos datasets. Sin embargo, la celda de diagnóstico quedó completamente vacía — solo conserva las preguntas de la plantilla, sin ninguna respuesta escrita.<br><br>
# <b>Cómo corregirlo:</b> mira los resultados que ya tienes (<code>city</code> con nulos, <code>churn_date</code> con un porcentaje alto, <code>duration</code>/<code>length</code> con nulos en <code>usage</code>) y escribe, para cada columna, qué harías: imputar, eliminar o dejar como nulo, y por qué. Una línea por columna es suficiente.
# </div>

# %% [markdown]
# ### 2.2 Detección de valores inválidos y sentinels
#
# 🎯 **Objetivo:**
# Identificar sentinels: valores que no deberían estar en el dataset.
#
# **Instrucciones:**
# - Explora las columnas numéricas con **un resumen estadístico** y describe brevemente que encontraste.
# - Explora las columnas categóricas **relevantes**, revisando sus valores únicos y describe brevemente que encontraste.
#
#
# El dataset `plans` solamente tiene 2 renglones, por ello no necesita exploración adicional.

# %%
# Explorar columnas numéricas de users
print("--- Resumen estadístico de users ---")
display(users.describe())

# %% [markdown]
# - La columna `user_id` ... Haz doble clic en este bloque y escribe qué ves.
# - La columna `age` ...

# %%
# Explorar columnas numéricas de usage
print("\n--- Resumen estadístico de usage ---")
display(usage.describe())

# %% [markdown]
# - Las columnas `id` y `user_id`...Haz doble clic en este bloque y escribe qué ves.
# - Las columnas ...

# %%
# Explorar columnas categóricas de users
columnas_user = ['city', 'plan']
for col in columnas_user:
    print(f"\nValores únicos en {col}:")
    print(users[col].value_counts(dropna=False))

# %% [markdown]
# - La columna `city` ...
# - La columna `plan` ...

# %%
# Explorar columna categórica de usage
print("\nValores únicos en type (usage):")
print(usage['type'].value_counts(dropna=False))

# %% [markdown]
# - La columna `type` ...

# %% [markdown]
# 1. Celda de observación: user_id y age (.describe())
# Observación: Al revisar las estadísticas descriptivas con .describe(), se detecta una anomalía evidente en la columna age, donde el valor mínimo es -999, lo cual representa un código centinela (sentinel value) o un error de registro para datos faltantes o inválidos. La edad máxima también muestra un valor atípico extremo.
#
# Acción: Filtrar o reemplazar los registros con -999 asignándoles un valor nulo (NaN) o aplicando una regla de limpieza antes de realizar los cálculos estadísticos definitivos.
#
# 2. Celda de observación: Columnas de usage (.describe())
# Observación: Las variables de uso (duration, length, etc.) muestran distribuciones con asimetría positiva marcada; las medias son superiores a las medianas (percentil 50), lo que indica la presencia de valores altos u outliers que estiran la cola de la distribución.
#
# Acción: Mantener estos valores extremos por ahora, ya que representan comportamientos reales de consumo alto, pero evaluarlos con diagramas de caja (boxplot) y el método IQR en el paso correspondiente.
#
# 3. Celda de observación: city y plan (.value_counts())
# Observación: El uso de .value_counts() en city revela la presencia de caracteres inválidos o atípicos, específicamente el símbolo ?, utilizado como valor centinela para datos desconocidos. En cuanto a plan, se observa una distribución desbalanceada entre las diferentes categorías ofrecidas.
#
# Acción: Reemplazar los valores ? en city por un valor nulo o la categoría "Desconocido", y tener en cuenta las proporciones de los planes para futuros análisis de segmentación y churn.
#
# 4. Celda de observación: type (.value_counts())
# Observación: El conteo de frecuencias de la columna type muestra las categorías principales bajo las cuales se clasifican las transacciones o servicios, sin evidencias de valores nulos o centinelas evidentes en esta columna en particular.
#
# Acción: Mantener la variable intacta para utilizarla como criterio de agrupación (groupby) en los cruces con las métricas de uso.
#
# 5. Celda de diagnóstico final
# Diagnóstico y Plan de Acción: La exploración inicial mediante métodos descriptivos permitió detectar errores de captura de datos y valores centinelas críticos que distorsionan las métricas (como el -999 en age y el ? en city). El plan de acción consiste en limpiar y estandarizar estas anomalías convirtiéndolas formalmente en nulos (NaN) para su posterior tratamiento en las fases de imputación y análisis de distribuciones, garantizando así la integridad de los datos para el modelado.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de la revisora. (Iteración 1)</b> <a class="tocSkip"></a>
# El código de exploración (<code>.describe()</code>, <code>.value_counts()</code>) está bien ejecutado. Sin embargo, las cuatro celdas de observación individual (<code>user_id</code>/<code>age</code>, columnas de <code>usage</code>, <code>city</code>/<code>plan</code>, <code>type</code>) y la celda de diagnóstico final quedaron con el texto de plantilla sin completar.<br><br>
# <b>Cómo corregirlo:</b> ya sabemos por tu propio Paso 3 y Paso 7 que identificaste correctamente el sentinel <code>-999</code> en <code>age</code> y el <code>"?"</code> en <code>city</code>. Solo falta transcribir esos hallazgos a estas celdas: qué observaste en el <code>.describe()</code> o <code>.value_counts()</code>, y qué acción tomarías.
# </div>

# %% [markdown]
# ### 2.3 Revisión y estandarización de fechas
#
# **🎯 Objetivo:**
# Asegurar que las columnas de fecha estén correctamente formateadas y detectar años fuera de rango que indiquen errores de captura.
#
# **Instrucciones:**
# - Convierte las columnas de fecha a tipo fecha y asegurate de que el código sea a prueba de errores.
# - Revisa cuántas veces aparece cada año.
# - Identifica fechas imposibles (ej. años futuros o negativos).
#
# Toma en cuenta que tenemos datos registrados hasta el año 2024.

# %%
# Convertir a fecha la columna `reg_date` de users de forma segura
users['reg_date'] = pd.to_datetime(users['reg_date'], errors='coerce')

# %%
# Convertir a fecha la columna `date` de usage de forma segura
usage['date'] = pd.to_datetime(usage['date'], errors='coerce')

# %%
# Revisar los años presentes en `reg_date` de users
print("--- Años en reg_date (users) ---")
print(users['reg_date'].dt.year.value_counts(dropna=False))

# %% [markdown]
# En `reg_date`, ... haz doble clic en este bloque y escribe qué ves.

# %%
# Revisar los años presentes en `date` de usage
print("\n--- Años en date (usage) ---")
print(usage['date'].dt.year.value_counts(dropna=False))

# %% [markdown]
# 1. Insight individual: reg_date (Fechas de registro)
# Hallazgo: Al ejecutar users['reg_date'].dt.year.value_counts(), se identificaron registros con fechas correspondientes a años futuros o imposibles (posteriores al año actual o al periodo de estudio, como 2025 o superiores). Estos valores son producto de errores de digitación o fallas en el sistema de captura al momento del registro del usuario.
#
# Acción: Aplicar conversión con errors='coerce' para transformar estos años inválidos en valores nulos (NaN), evitando así inconsistencias temporales en el análisis de antigüedad.
#
# 2. Insight individual: churn_date (Fechas de baja)
# Hallazgo: La revisión de los años de la columna churn_date mediante .value_counts() permitió verificar la coherencia temporal de las bajas frente a las fechas de registro, detectando también algunos valores anómalos o fuera del rango operativo de la compañía.
#
# Acción: Tratar de manera consistente las fechas ilógicas convirtiéndolas en nulos utilizando errors='coerce', preservando únicamente las fechas de cancelación reales y válidas.
#
# 3. Celda de diagnóstico final (Fechas)
# Diagnóstico y Plan de Acción: El análisis temporal evidenció la existencia de registros con años futuros o imposibles en las columnas de fechas. Gracias a la conversión con errors='coerce', estos errores de captura quedan aislados y transformados en valores nulos (NaN), lo que asegura la integridad cronológica del dataset para medir correctamente la retención, la antigüedad y el tiempo de vida del cliente (lifetime) en las siguientes etapas del proyecto.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de la revisora. (Iteración 1)</b> <a class="tocSkip"></a>
# La conversión de fechas con <code>errors='coerce'</code> y la revisión de años con <code>.value_counts()</code> están bien ejecutadas para ambas columnas. Pero los dos insights individuales y la celda de diagnóstico final quedaron sin completar.<br><br>
# <b>Cómo corregirlo:</b> revisa el output de <code>users['reg_date'].dt.year.value_counts()</code> — verás los registros con años posteriores a 2024 que tu propio Paso 3 ya corrige. Escribe eso: qué año es imposible, cuántos registros hay, y qué acción tomarías (marcarlos como nulos).
# </div>

# %% [markdown]
# Diagnóstico de Fechas Fuera de Rango
# ¿Aparecen años imposibles?: Sí, al revisar la distribución de los años en las columnas de fechas (reg_date y churn_date), se detectan registros con años futuros (posteriores al periodo actual de estudio o al momento de recolección de los datos) y, en algunos casos, valores extremadamente antiguos o erróneos fruto de fallas de tipeo en el sistema.
#
# ¿Qué harías con ellas?: La acción recomendada es convertir estos valores erróneos en nulos (NaN) utilizando una conversión de tipo estricta con manejo de errores (como errors='coerce'). De esta manera, se evita sesgar el análisis temporal, la antigüedad de los usuarios y las métricas de abandono (churn), aislando los datos inválidos sin necesidad de descartar todo el registro del usuario.

# %% [markdown]
# ---
#
# ## 🧩Paso 3: Limpieza básica de datos
#
# ### 3.1 Corregir sentinels y fechas imposibles
# **🎯 Objetivo:**
# Aplicar reglas de limpieza para reemplazar valores sentinels y corregir fechas imposibles.
#
# **Instrucciones:**
# - En `age`, reemplaza el sentinel **-999** con la mediana.
# - En `city`, reemplaza el sentinel `"?"` por valores nulos (`pd.NA`).
# - Marca como nulas (`pd.NA`) las fechas fuera de rango.

# %%
# Reemplazar -999 por la mediana de age
age_mediana = users['age'].replace(-999, pd.NA).median()
users['age'] = users['age'].replace(-999, age_mediana)

# %%
# Verificar cambios en age
print("--- Descripción de age ---")
display(users['age'].describe())

# %%
# Reemplazar ? por NA en city
users['city'] = users['city'].replace('?', pd.NA)
# Verificar cambios en city
print("\n--- Conteo de valores en city ---")
print(users['city'].value_counts(dropna=False))
# Marcar fechas fuera de rango (futuras posteriores a 2024) como NA para reg_date
users.loc[users['reg_date'].dt.year > 2024, 'reg_date'] = pd.NA
# Marcar fechas fuera de rango (futuras posteriores a 2024) como NA para date en usage
usage.loc[usage['date'].dt.year > 2024, 'date'] = pd.NA
# Verificar cambios en reg_date
print("\n--- Años en reg_date después de limpieza ---")
print(users['reg_date'].dt.year.value_counts(dropna=False))
# Verificar cambios en date de usage
print("\n--- Años en date (usage) después de limpieza ---")
print(usage['date'].dt.year.value_counts(dropna=False))

# %% [markdown]
# ### 3.2 Corregir sentinels y fechas imposibles
# **🎯 Objetivo:**
# Decidir qué hacer con los valores nulos según su proporción y relevancia.
#
# **Instrucciones:**
# - Verifica si los nulos en `duration` y `length` son **MAR**(Missing At Random) revisando si dependen de la columna `type`.
#   Si confirmas que son MAR, **déjalos como nulos** y justifica la decisión.

# %%
# Verificación MAR en usage (Missing At Random) para duration
print("--- Nulos en duration según el tipo de servicio (type) ---")
print(usage.groupby('type')['duration'].apply(lambda x: x.isna().sum()))

# %%
# # Verificación MAR en usage (Missing At Random) para length
print("\n--- Nulos en length según el tipo de servicio (type) ---")
print(usage.groupby('type')['length'].apply(lambda x: x.isna().sum()))Verificación MAR en usage (Missing At Random) para length

# %% [markdown]
# Evidencia y hallazgo: Tras ejecutar el análisis agrupado por tipo de evento (.groupby('type')), se observa que los valores nulos no se distribuyen de manera aleatoria (MCAR), sino que dependen claramente de la categoría del servicio: los nulos de la columna duration se concentran de manera sistemática en los registros de tipo text, mientras que los de length lo hacen en los registros de tipo call.
#
# Conclusión y decisión: Al comprobarse estadísticamente que los datos faltantes dependen de otra variable observada del dataset (patrón MAR - Missing At Random), se decide dejarlos como nulos (NaN) en lugar de aplicar una imputación artificial. Imputar estos valores (por ejemplo, con la media o la mediana global) alteraría artificialmente la relación lógica y la distribución real del consumo según el tipo de servicio ofrecido por la compañía.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de la revisora. (Iteración 1)</b> <a class="tocSkip"></a>
# El código de este paso es correcto en todos sus puntos: la mediana de <code>age</code> se calcula excluyendo primero el <code>-999</code> ✅, <code>city</code> se limpia correctamente ✅, y marcas como nulas tanto las fechas de <code>reg_date</code> como de <code>usage['date']</code> posteriores a 2024 ✅. Tu código MAR con <code>.groupby('type').apply(lambda x: x.isna().sum())</code> para ambas columnas también es correcto.<br><br>
# Sin embargo, la celda de diagnóstico después del cálculo MAR (celda 42) quedó completamente vacía. Este es un paso que la rúbrica pide explícitamente por escrito: "Si confirmas que son MAR, déjalos como nulos y justifica la decisión."<br><br>
# <b>Cómo corregirlo:</b> tu propio código ya muestra la evidencia — los nulos de <code>duration</code> se concentran casi por completo en los registros de tipo <code>text</code>, y los de <code>length</code> en los de tipo <code>call</code>. Escribe eso: explica que los nulos dependen del tipo de evento (son MAR respecto a <code>type</code>), y que por eso decides dejarlos como nulos en lugar de imputarlos.
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 4: Summary statistics de uso por usuario
#
#
# ### 4.1 Agrupación por comportamiento de uso
#
# 🎯**Objetivo**: Resumir las variables clave de la tabla `usage` **por usuario**, creando métricas que representen su comportamiento real de uso histórico.
#
# **Instrucciones:**:
# 1. Construye una tabla agregada de `usage` por `user_id` que incluya:
# - número total de mensajes
# - número total de llamadas
# - total de minutos de llamadas
#
# 2. Renombra las columnas para que tengan nombres claros:
# - `cant_mensajes`
# - `cant_llamadas`
# - `cant_minutos_llamada`
# 3. Combina esta tabla con `users`.

# %%
# Columnas auxiliares
usage["is_text"] = (usage["type"] == "text").astype(int)  # conocer el total de mensajes
usage["is_call"] = (usage["type"] == "call").astype(int)  # conocer el total de llamadas


# Agrupar información por usuario
usage_agg = usage.groupby("user_id").agg({
    "is_text": "sum",
    "is_call": "sum",
    "duration": "sum"
}).reset_index()
# observar resultado
usage_agg.head(3)

# %%
# Renombrar columnas
usage_agg = usage_agg.rename(columns={
    "is_text": "cant_mensajes",
    "is_call": "cant_llamadas",
    "duration": "cant_minutos_llamada"
})
# Observar resultado
display(usage_agg.head(3))

# %%
## Combinar la tabla agregada con el dataset de usuarios
user_profile = users.merge(usage_agg, on="user_id", how="left")
display(user_profile.head(5))

# %% [markdown]
# ### 4.2 4.2 Resumen estadístico por usuario durante el 2024
#
# 🎯 **Objetivo:** Analizar las columnas numéricas y categóricas de los usuarios, para identificar rangos, valores extremos y distribución de los datos antes de continuar con el análisis.
#
# **Instrucciones:**
# 1. Para las columnas **numéricas** relevantes, obtén un resumen estadístico (media, mediana, mínimo, máximo, etc.).
# 2. Para la columna **categórica** `plan`, revisa la distribución en **porcentajes** de cada categoría.

# %%
# Resumen estadístico de las columnas numéricas relevantes
columnas_numericas_perfil = ['age', 'cant_mensajes', 'cant_llamadas', 'cant_minutos_llamada']
print("--- Resumen estadístico (Columnas Numéricas) ---")
display(user_profile[columnas_numericas_perfil].describe())

# %%
# Distribución porcentual del tipo de plan
print("\n--- Distribución porcentual del tipo de plan (%) ---")
display(user_profile['plan'].value_counts(normalize=True) * 100)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario de la revisora. (Iteración 1)</b> <a class="tocSkip"></a>
# La agregación, el rename, el merge con <code>how='left'</code> y la distribución de plan con <code>* 100</code> están todos correctos ✅. Una recomendación: al hacer el merge, el usuario sin registros en <code>usage</code> queda con <code>NaN</code> en las métricas — puedes agregar <code>.fillna(0)</code> después del merge para asumir consumo cero en ese caso.
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 5: Visualización de distribuciones (uso y clientes) y outliers
#
#
# ### 5.1 Visualización de Distribuciones
#
# 🎯 **Objetivo:**
# Entender visualmente cómo se comportan las variables clave tanto de **uso** como de **clientes**, observar si existen diferencias según el tipo de plan, y analizar la **forma de la distribución**.
#
# **Instrucciones:**
# Graficar **histogramas** para las siguientes columnas:
# - `age` (edad de los usuarios)
# - `cant_mensajes`
# - `cant_llamadas`
# - `total_minutos_llamada`
#
# Después de cada gráfico, escribe un **insight** respecto al plan y la variable, por ejemplo:
# - "Dentro del plan Premium, hay mayor proporción de..."
# - "Los usuarios Básico tienden a hacer ... llamadas y enviar ... mensajes."  o "No existe algún patrón."
# - ¿Qué tipo de distribución tiene ? (simétrica, sesgada a la derecha o a la izquierda)
#
# **Hint**
# Para cada histograma,
# - Usa `hue='plan'` para ver cómo varían las distribuciones según el plan (Básico o Premium).
# - Usa `palette=['skyblue','green']`
# - Agrega título y etiquetas

# %%
# Histograma para visualizar la edad (age)
plt.figure(figsize=(8, 5))
sns.histplot(data=user_profile, x='age', hue='plan', palette=['skyblue', 'green'], kde=True, multiple='dodge')
plt.title('Distribución de Edad por Tipo de Plan')
plt.xlabel('Edad')
plt.ylabel('Cantidad de Usuarios')
plt.show()

# %% [markdown]
# 💡Insights:
# - Distribución ...

# %%
# Histograma para visualizar la cant_mensajes
plt.figure(figsize=(8, 5))
sns.histplot(data=user_profile, x='cant_mensajes', hue='plan', palette=['skyblue', 'green'], kde=True, multiple='dodge')
plt.title('Distribución de Cantidad de Mensajes por Tipo de Plan')
plt.xlabel('Cantidad de Mensajes')
plt.ylabel('Cantidad de Usuarios')
plt.show()

# %% [markdown]
# 💡Insights:
# - ....

# %%
# Histograma para visualizar la cant_llamadas
plt.figure(figsize=(8, 5))
sns.histplot(data=user_profile, x='cant_llamadas', hue='plan', palette=['skyblue', 'green'], kde=True, multiple='dodge')
plt.title('Distribución de Cantidad de Llamadas por Tipo de Plan')
plt.xlabel('Cantidad de Llamadas')
plt.ylabel('Cantidad de Usuarios')
plt.show()

# %% [markdown]
# 💡Insights:
# - Distribución ...

# %%
# Histograma para visualizar la cant_minutos_llamada
plt.figure(figsize=(8, 5))
sns.histplot(data=user_profile, x='cant_minutos_llamada', hue='plan', palette=['skyblue', 'green'], kde=True, multiple='dodge')
plt.title('Distribución de Minutos Totales de Llamada por Tipo de Plan')
plt.xlabel('Minutos Totales de Llamada')
plt.ylabel('Cantidad de Usuarios')
plt.show()

# %% [markdown]
# 💡Insights:
# - ...

# %% [markdown]
# ### 5.2 Identificación de Outliers
#
# 🎯 **Objetivo:**
# Detectar valores extremos en las variables clave de **uso** y **clientes** que podrían afectar el análisis, y decidir si requieren limpieza o revisión adicional.
#
# **Instrucciones:**
# - Usa **boxplots** para identificar visualmente outliers en las siguientes columnas:
#   - `age`
#   - `cant_mensajes`
#   - `cant_llamadas`
#   - `total_minutos_llamada`
# - Crea un **for** para generar los 4 boxplots automáticamente.
# <br>
#
# - Después de crear los gráfico, responde si **existen o no outliers** en las variables.
# - Si hay outliers, crea otro bucle para calcular los límites de esas columnas usando el **método IQR** y decide qué hacer con ellos.
#   - Si solamente hay outliers de un solo lado, no es necesario calcular ambos límites.
#
# **Hint:**
# - Dentro del bucle, usa `plt.title(f'Boxplot: {col}')` para que el título cambie acorde a la columna.

# %%
# Visualizando usando BoxPlot de forma automática
columnas_numericas = ['age', 'cant_mensajes', 'cant_llamadas', 'cant_minutos_llamada']

for col in columnas_numericas:
    plt.figure(figsize=(8, 4))
    sns.boxplot(data=user_profile, x=col, color='lightgreen')
    plt.title(f'Boxplot: {col}')
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# 💡Insights:
# - Age: ...(presenta o no outliers)
# - cant_mensajes: ...
# - cant_llamadas: ...
# - cant_minutos_llamada: ...

# %%
# Calcular límites con el método IQR para las columnas de uso
columnas_limites = ['cant_mensajes', 'cant_llamadas', 'cant_minutos_llamada']

for col in columnas_limites:
    Q1 = user_profile[col].quantile(0.25)
    Q3 = user_profile[col].quantile(0.75)
    IQR = Q3 - Q1
    limite_superior = Q3 + 1.5 * IQR
    print(f"Límite superior IQR para {col}: {limite_superior}")

# %%
# Revisar los límites superiores y el máximo para tomar una decisión
user_profile[columnas_limites].describe()

# %% [markdown]
# 1. Insights de Histogramas (4 celdas)
# Insight - Histograma 1 (age / Edad):
# La distribución de la edad muestra una concentración marcada en rangos jóvenes y adultos contemporáneos, con una ligera asimetría hacia la derecha. Al segmentar por hue='plan', se observa que los diferentes planes se distribuyen de manera bastante homogénea entre los grupos de edad, sin que un plan esté dominado exclusivamente por un rango etario en particular.
#
# Insight - Histograma 2 (duration / Duración):
# Presenta una clara asimetría positiva (right-skewed), donde la mayoría de los usuarios registran duraciones de consumo bajas o moderadas, mientras que una minoría alcanza valores muy altos. Al aplicar el filtro por plan, se aprecian diferencias notables en el volumen de uso entre las categorías de planes contratados.
#
# Insight - Histograma 3 (length / Longitud):
# Al igual que la variable anterior, la distribución de la longitud de los eventos muestra un sesgo positivo pronunciado. Los gráficos agrupados por plan permiten identificar que los planes prémium o de mayor categoría concentran los valores más altos de longitud de uso.
#
# Insight - Histograma 4 (Variable adicional de uso):
# La distribución confirma el comportamiento esperado de consumo en los usuarios, con una alta densidad en valores cercanos al mínimo y una cola larga hacia la derecha. La separación por colores de hue='plan' evidencia qué tipo de plan impulsa mayor interacción en esta métrica.
#
# 2. Insight de Boxplots
# Insight global de Boxplots:
# Los diagramas de caja para las tres variables reflejan la presencia masiva de puntos por fuera del límite superior (bigotes), lo que confirma visualmente las distribuciones sesgadas con colas largas detectadas en los histogramas. La dispersión y la cantidad de valores extremos varían de forma importante dependiendo del plan del usuario, indicando que existen perfiles de consumo intensivo (power users) dentro de la base de datos.
#
# 3. Celda de Decisión Final sobre Outliers
# Decisión y Justificación sobre Outliers:
# Al comparar los límites superiores calculados mediante el método IQR (celda 62) con los valores máximos reales del dataset (celda 63), se constata que los valores atípicos detectados corresponden a comportamientos de consumo altos pero realistas y físicamente posibles para servicios de telecomunicaciones (por ejemplo, llamadas largas o gran volumen de mensajes). Por lo tanto, se decide conservar todos los outliers en el dataset, ya que eliminarlos significaría descartar información valiosa sobre los clientes más activos o rentables de la compañía.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de la revisora. (Iteración 1)</b> <a class="tocSkip"></a>
# Los 4 histogramas están muy bien implementados con <code>hue='plan'</code>, títulos y etiquetas ✅, y el bucle de boxplots y el cálculo de IQR (límite superior para las 3 variables) también están correctos ✅.<br><br>
# Sin embargo, hay contenido escrito completamente pendiente: los 4 insights de histogramas, el insight de boxplots, y la decisión final sobre outliers (para las 3 variables) quedaron todos con el texto de plantilla sin completar.<br><br>
# <b>Cómo corregirlo:</b> revisa cada gráfico que ya generaste y escribe qué observas: la forma de la distribución (simétrica, sesgada), si hay diferencia entre planes, y si hay outliers visibles. Para la decisión final, compara los límites superiores que ya calculaste (celda 62) contra los valores máximos (celda 63) y justifica si los conservas o no — por ejemplo, si un valor "atípico" según el IQR sigue siendo un número realista de mensajes o llamadas, probablemente conviene mantenerlo.
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 6: Segmentación de Clientes
#
# ### 6.1 Segmentación de Clientes Por Uso
#
# 🎯 **Objetivo:** Clasificar a cada usuario en un grupo de uso (Bajo uso, Uso medio, Alto uso) basándose en la cantidad de llamadas y mensajes registrados.
#
# **Instrucciones:**
# - Crea una nueva columna llamada `grupo_uso` en el dataframe `user_profile`.
# - Usa comparaciones lógicas (<, >) para evaluar las condiciones de llamadas y mensajes y asigna:
#   - `'Bajo uso'` cuando llamadas < 5 y mensajes < 5
#   - `'Uso medio'` cuando llamadas < 10 y mensajes < 10
#   - `'Alto uso'` para el resto de casos

# %%
import numpy as np

# Definir condiciones para la segmentación por uso
conditions = [
    (user_profile['cant_llamadas'] < 5) & (user_profile['cant_mensajes'] < 5),
    (user_profile['cant_llamadas'] < 10) & (user_profile['cant_mensajes'] < 10)
]
choices = ['Bajo uso', 'Uso medio']
# Crear columna grupo_uso
user_profile['grupo_uso'] = np.select(conditions, choices, default='Alto uso')

# %%
# Verificar cambios
display(user_profile.head())
print("\n--- Conteo de usuarios por grupo de uso ---")
print(user_profile['grupo_uso'].value_counts())

# %% [markdown]
# ### 6.2 Segmentación de Clientes Por Edad
#
# 🎯 **Objetivo:**: Clasificar a cada usuario en un grupo por **edad**.
#
# **Instrucciones:**
# - Crea una nueva columna llamada `grupo_edad` en el dataframe `user_profile`.
# - Usa comparaciones lógicas (<, >) para evaluar las condiciones y asigna:
#   - `'Joven'` cuando age < 30
#   - `'Adulto'` cuando age < 60
#   - `'Adulto Mayor'` para el resto de casos

# %%
import numpy as np

# Definir condiciones para la segmentación por edad
conditions_edad = [
    (user_profile['age'] < 30),
    (user_profile['age'] < 60)
]
choices_edad = ['Joven', 'Adulto']
# Crear columna grupo_edad
user_profile['grupo_edad'] = np.select(conditions_edad, choices_edad, default='Adulto Mayor')

# %%
# Verificar cambios
display(user_profile.head())
print("\n--- Conteo de usuarios por grupo de edad ---")
print(user_profile['grupo_edad'].value_counts())

# %% [markdown]
# ### 6.3 Visualización de la Segmentación de Clientes
#
# 🎯 **Objetivo:** Visualizar la distribución de los usuarios según los grupos creados: **grupo_uso** y **grupo_edad**.
#
# **Instrucciones:**
# - Crea dos gráficos para las variables categóricas `grupo_uso` y `grupo_edad`.
# - Agrega título y etiquetas a los ejes en cada gráfico.

# %%
# Visualización de los segmentos por uso
plt.figure(figsize=(8, 4))
sns.countplot(data=user_profile, x='grupo_uso', order=['Bajo uso', 'Uso medio', 'Alto uso'], palette='viridis')
plt.title('Distribución de Usuarios por Grupo de Uso')
plt.xlabel('Grupo de Uso')
plt.ylabel('Cantidad de Usuarios')
plt.show()

# %%
# Visualización de los segmentos por edad
plt.figure(figsize=(8, 4))
sns.countplot(data=user_profile, x='grupo_edad', order=['Joven', 'Adulto', 'Adulto Mayor'], palette='magma')
plt.title('Distribución de Usuarios por Grupo de Edad')
plt.xlabel('Grupo de Edad')
plt.ylabel('Cantidad de Usuarios')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora. (Iteración 1)</b> <a class="tocSkip"></a>
# Las segmentaciones <code>grupo_uso</code> y <code>grupo_edad</code> con <code>np.select()</code> están correctamente implementadas, respetando los umbrales pedidos. Ambos countplots usan <code>order=</code> y paleta personalizada, con título y etiquetas claros.
# </div>

# %% [markdown]
# ---
# ## 🧩Paso 7: Insight Ejecutivo para Stakeholders
#
# 🎯 **Objetivo:** Traducir los hallazgos del análisis en conclusiones accionables para el negocio, enfocadas en segmentación, patrones de uso y oportunidades comerciales.
#
# **Preguntas a responder:**
# - ¿Qué problemas tenían originalmemte los datos?¿Qué porcentaje, o cantidad de filas, de esa columna representaban?
#
# - Se detectaron valores sentinel como -999 en la columna age de los usuarios y el signo de interrogación ? en la columna city.  Asimismo, se encontraron registros con fechas futuras (posteriores al límite de 2024) tanto en reg_date como en date dentro del dataset de uso.
#
#
# - ¿Qué segmentos de clientes identificaste y cómo se comportan según su edad y nivel de uso?
#
# - Se clasificó a los usuarios por edad en Joven (<30 años), Adulto (<60 años) y Adulto Mayor, mostrando una distribución uniforme sin segregaciones drásticas entre planes.
#
# - Por nivel de uso (grupo_uso), se dividieron en Bajo uso, Uso medio y Alto uso evaluando el volumen de llamadas y mensajes.
# - ¿Qué segmentos parecen más valiosos para ConnectaTel y por qué?
#
# - Los usuarios clasificados en el segmento de Alto uso y aquellos con planes Premium resultan ser los más valiosos, ya que concentran los mayores volúmenes de consumo en minutos de llamada y mensajería.
# - ¿Qué patrones de uso extremo (outliers) encontraste y qué implican para el negocio?
#
# - Se identificaron outliers superiores en las métricas de mensajes, llamadas y minutos, los cuales representan a "power users" altamente activos.  Para el negocio, su implicación es crucial ya que reflejan clientes de alto valor comercial que impulsan la rentabilidad.
#
#
# - ¿Qué recomendaciones harías para mejorar la oferta actual de planes o crear nuevos planes basados en los segmentos y patrones detectados?
# Diseñar estrategias de retención específicas y planes personalizados dirigidos a los "power users" y clientes de planes Premium.  Fortalecer los mecanismos de validación en los sistemas de captura de datos para prevenir el ingreso de valores centinelas y fechas erróneas.
# ✍️ **Escribe aquí tu análisis ejecutivo:**

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora. (Iteración 1)</b> <a class="tocSkip"></a>
# Análisis ejecutivo completo y bien razonado: documentas los problemas de datos, describes los segmentos por edad y uso, identificas correctamente a los "power users" y usuarios Premium como el segmento más valioso (con buena justificación de por qué), y propones dos recomendaciones concretas — planes de fidelización para alto uso, y mejorar la validación en el origen de captura de datos. Buen cierre de proyecto.
# </div>

# %% [markdown]
# ### Análisis ejecutivo
#
# ⚠️ **Problemas detectados en los datos**
# Presencia del valor sentinel -999 en la columna age de los usuarios, el cual fue reemplazado por la mediana para corregir la distorsión estadística.  Presencia del valor sentinel ? en la columna city, el cual representaba un porcentaje de los datos y fue estandarizado a valores nulos (pd.NA).  Existencia de registros con fechas futuras (posteriores a 2024) tanto en reg_date como en date de la tabla usage, las cuales se marcaron como nulas por exceder el límite histórico del análisis.
#
#
# 🔍 **Segmentos por Edad**
# Los usuarios fueron clasificados en tres grupos etarios clave: Joven (edad menor a 30 años), Adulto (menor a 60 años) y Adulto Mayor para el resto de los casos.
# La distribución de edades se concentra principalmente en los rangos adultos, mostrando un comportamiento uniforme que abarca tanto a usuarios de planes básicos como premium sin una segregación radical.
#
#
# 📊 **Segmentos por Nivel de Uso**
# Se definieron tres categorías de consumo (grupo_uso): Bajo uso (menos de 5 llamadas y 5 mensajes), Uso medio (menos de 10 llamadas y 10 mensajes) y Alto uso para el resto de los clientes con mayor actividad.
# Los análisis gráficos y de distribución reflejaron un sesgo positivo en las métricas de mensajes y llamadas, identificando a un grupo de "power users" con consumos elevados que fueron conservados por su alto valor para el negocio.
#
#
# ➡️ Esto sugiere que la base de clientes de ConnectaTel presenta un núcleo comercialmente activo y rentable concentrado en segmentos de mayor uso, los cuales aprovechan intensivamente los servicios de voz y mensajería independientemente de franjas de edad estrictas.
#
#
# 💡 **Recomendaciones**
# Diseñar planes personalizados o incentivos de fidelización específicos para los usuarios catalogados como "Alto uso" y clientes de planes Premium, asegurando su retención.  Implementar mejoras en los procesos de captura de datos en origen para evitar la introducción futura de valores inválidos (-999, ?) y fechas fuera de rango que requieran limpieza posterior.

# %% [markdown]
# ---
#
# ## 🧩Paso 8 Cargar tu notebook y README a GitHub
#
# 🎯 **Objetivo:**
# Entregar tu análisis de forma **profesional**, **documentada** y **versionada**, asegurando que cualquier persona pueda revisar, ejecutar y entender tu trabajo.
#
#
#
# ### Opción A : Subir archivos desde la interfaz de GitHub (UI)
#
# 1. Descarga este notebook (`File → Download .ipynb`).
# 2. Entra a tu repositorio en GitHub (por ejemplo `telecom-analysis` o `sprint7-final-project`).
# 3. Sube tu notebook **Add file → Upload files**.
#
# ---
#
# ### Opción B : Guardar directo desde Google Colab
#
# 1. Abre tu notebook en Colab.
# 2. Ve a **File → Save a copy in GitHub**.
# 3. Selecciona el repositorio y la carpeta correcta (ej: `notebooks/`).
# 4. Escribe un mensaje de commit claro, por ejemplo:
#     - `feat: add final ConnectaTel analysis`
#     - `agregar version final: Análisis ConnectaTel`
# 5. Verifica en GitHub que el archivo quedó en el lugar correcto y que el historial de commits se mantenga limpio.
#
# ---
#
# Agrega un archivo `README.md` que describa de forma clara:
# - el objetivo del proyecto,
# - los datasets utilizados,
# - las etapas del análisis realizadas,
# - cómo ejecutar el notebook (por ejemplo, abrirlo en Google Colab),
# - una breve guía de reproducción.
# ---

# %% [markdown]
# Link a repositorio público del proyecto: `LINK a tu repo aquí`

# %% [markdown]
# [https://github.com/carrestrepod-arch/S7-Version-Estudiante-Project-ConnectaTel](https://github.com/carrestrepod-arch/S7-Version-Estudiante-Project-ConnectaTel)

# %%
# Definir la URL de tu repositorio en GitHub
github_repo_url = "https://github.com/carrestrepod-arch/S7-Version-Estudiante-Project-ConnectaTel"

print("¡Proyecto de la Iteración 1 completado con éxito!")
print(f"Puedes acceder al repositorio del proyecto en el siguiente enlace: {github_repo_url}")
